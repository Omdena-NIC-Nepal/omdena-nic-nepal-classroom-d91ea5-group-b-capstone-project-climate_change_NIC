# %%
import pandas as pd
import numpy as np
import seaborn as sns
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
rivers_data = pd.read_csv("X:/AI DataScience projects/Assignment 8/capstone-project-KarunBhandari/Weather_&_Climate_Data/Historical temperature, precipitation, and weather events/raw/glacier_and_river_data/major-rivers-in-nepal.csv")
glaciar_data = pd.read_csv("X:/AI DataScience projects/Assignment 8/capstone-project-KarunBhandari/Weather_&_Climate_Data/Historical temperature, precipitation, and weather events/raw/glacier_and_river_data/glaciers-glacial-lakes-and-major-river-basins.csv")

# %%
'''print("\n Basic Information --")
print(glaciar_data.info())
print(rivers_data.info())

print("--Data Preview--")
print(rivers_data.head())
print(glaciar_data.head())

# Shape
print(f"\nDataset contains {rivers_data.shape[0]} rows and {rivers_data.shape[1]} columns.")
print(f"\nDataset contains {glaciar_data.shape[0]} rows and {glaciar_data.shape[1]} columns.")

# Columns
print("\n--- Column Names ---")
print(list(rivers_data.columns))
print(list(glaciar_data.columns))

# Missing values
print("\n--- Missing Values ---")
print(rivers_data.isnull().sum())
print(glaciar_data.isnull().sum())

# Data types
print("\n--- Data Types ---")
print(rivers_data.dtypes)
print(glaciar_data.dtypes)
# Summary statistics (numerical)
print("\n--- Summary Statistics (Numerical Columns) ---")
print(rivers_data.describe())
print(glaciar_data.describe())
# Summary statistics (categorical)'''
categorical_cols_rivers = rivers_data.select_dtypes(include=['object']).columns
categorical_cols = glaciar_data.select_dtypes(include=['object']).columns
print("\n--- Summary Statistics (Categorical Columns) ---")
print(rivers_data[categorical_cols_rivers])
print(glaciar_data[categorical_cols])
# Out:
# --- Summary Statistics (Categorical Columns) ---
#           River                              River Attribute
# 0      Mahakali                  Drainage Area (km²) - Total
# 1       Karnali                  Drainage Area (km²) - Total
# 2         Babai                  Drainage Area (km²) - Total
# 3    West Rapti                  Drainage Area (km²) - Total
# 4      Narayani                  Drainage Area (km²) - Total
# 5       Bagmati                  Drainage Area (km²) - Total
# 6      Sapkoshi                  Drainage Area (km²) - Total
# 7        Kankai                  Drainage Area (km²) - Total
# 8   Other River                  Drainage Area (km²) - Total
# 9      Mahakali                  Drainage Area (km²) - Nepal
# 10      Karnali                  Drainage Area (km²) - Nepal
# 11        Babai                  Drainage Area (km²) - Nepal
# 12   West Rapti                  Drainage Area (km²) - Nepal
# 13     Narayani                  Drainage Area (km²) - Nepal
# ...
